# %% [markdown]
# # Analysis of Global Refugee Movement
# # Urisha Kreem, Nidhi Allani, Ernev

# %% [markdown]
# # INTRODUCTION

# %% [markdown]
# The overall objective of this project is to analyze the global refugee movement taking place from the years 2000 to 2016. The primary goal is to inform the general public of the most frequent destination countries for refugees, how refugee flow has changed, and how the current trends present could predict future refugee patterns.
#
# The motivation and relevance of this topic is due to many reasons. One of the main reasons supported by a statistic, the United Nations has documented that over 70.8 million people around the world have been forced from home by conflict and persecution at the end of 2018 { https://www.un.org/en/sections/issues-depth/refugees/ }. This is very current information and the issue of refugees is not going away anytime soon.
#
# The relevance and importance of this topic in respect to data science is that through data analysis of the information we have access to, it will give us insight to crucial imformation to which we can see  what we can expect for the future of refugees based off of what we have seen in the past. From the data analysis conducted, refugees and others who assist refugees can gain deep insight such as getting a general sense of where assylum seekers have the best shot of being accepted.
#
# Throughout this tutorial we attempt to uncover these trends of refugee movement in a clear, concsice manner - making the data available at hand easy to be interpretted and understood by the public.

# %% [markdown]
# # DATA COLLECTION

# %% [markdown]
# # Imports:

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import pandas as pandas
import statsmodels.formula.api as sm
import statsmodels.api as stm
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn import datasets, linear_model

# %% [markdown]
# # Data Extraction

# %%
data = pd.read_csv("asylum_seekers.csv")
data
# Out:
#         Year Country / territory of asylum/residence       Origin  \
# 0       2000                                Zimbabwe  Afghanistan
# 1       2000                            South Africa  Afghanistan
# 2       2000                              Uzbekistan  Afghanistan
# 3       2000                United States of America  Afghanistan
# 4       2000                United States of America  Afghanistan
# ...      ...                                     ...          ...
# 129715  2016                United States of America     Zimbabwe
# 129716  2016                United States of America     Zimbabwe
# 129717  2016                            South Africa     Zimbabwe
# 129718  2016                            South Africa     Zimbabwe
# 129719  2016                                  Zambia     Zimbabwe
#
#        RSD procedure type / level Tota pending start-year  \
# 0                          G / FI                       0
# ...

# %% [markdown]
# From this extraction, we can see that there are quite a few values across the table that have values of 'NaN' or *. Essentially what this entails is that the data was unable to be collected, or is simply missing. To do further analysis we need to deal with these values in a strategic way. We chose to __ . Our group figured this was the best way to approach the missing information because __ .

# %%
# do something with NaN / * 
# display new dataframe

# %%
# explain what we did above
